# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.1 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (1.9.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (1.23.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (1.1.3)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (3.6.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: setuptools in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (65.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\gauri\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.21.0
# Could not find platform dependent libraries <exec_prefix>

# %%
import pandas as pd
import csv
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,association_rules

# %%
# making 2D array of items bought from shop by ith person
dataset = []
with open('Market_Basket_Optimisation.csv') as file:
    reader = csv.reader(file,delimiter=',')
    for row in reader:
        dataset+=[row]

# %%
dataset[0:10]
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries']]

# %%
len(dataset)
# Out:
# 7501

# %%
#Transaction encoder makes a table of items bought as column names
# and marks true for a person if he buys it 
#helps in collecting all the unique items
te = TransactionEncoder()
x = te.fit_transform(dataset)

# %%
x.shape
# Out:
# (7501, 120)

# %%
#Making a pandas dataframe as datase
df = pd.DataFrame(x,columns=te.columns_)
df
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  ...  whole wheat rice   yams  yogurt cake  zucchini
# 0          False     True               True      False  ...             False   True        False     False
# 1          False    False              False      False  ...             False  False        False     False
# 2          False    False              False      False  ...             False  False        False     False
# 3          False    False              False      False  ...             False  False        False     False
# 4          False    False              False      False  ...              True  False        False     False
# ...          ...      ...                ...        ...  ...               ...    ...          ...       ...
# 7496       False    False              False      False  ...             False  False        False     False
# 7497       False    False              False      False  ...             False  False        False     False
# 7498       False    False              False      False  ...             False  False        False     False
# 7499       False    False              False      False  ...             False  False        False     False
# 7500       False    False              False      False  ...             False  False         True     False
#
# [7501 rows x 120 columns]

# %%
# 1. Find frequent itemset
freq_itemset = apriori(df,min_support=0.01,use_colnames=True) # taking support as 10%

# %%
freq_itemset
# Out:
#       support                                 itemsets
# 0    0.020397                                (almonds)
# 1    0.033329                                (avocado)
# 2    0.010799                         (barbecue sauce)
# 3    0.014265                              (black tea)
# 4    0.011465                             (body spray)
# ..        ...                                      ...
# 252  0.011065       (milk, ground beef, mineral water)
# 253  0.017064  (spaghetti, ground beef, mineral water)
# 254  0.015731         (spaghetti, milk, mineral water)
# 255  0.010265    (spaghetti, olive oil, mineral water)
# 256  0.011465     (spaghetti, pancakes, mineral water)
#
# [257 rows x 2 columns]

# %%
# Find the rules
rules = association_rules(freq_itemset,metric='confidence',
min_threshold=0.30)
rules
# Out:
#                    antecedents      consequents  antecedent support  ...      lift  leverage  conviction
# 0                    (avocado)  (mineral water)            0.033329  ...  1.459926  0.003654    1.168147
# 1                    (burgers)           (eggs)            0.087188  ...  1.837830  0.013128    1.224818
# 2                       (cake)  (mineral water)            0.081056  ...  1.421397  0.008142    1.151921
# 3                    (cereals)  (mineral water)            0.025730  ...  1.673729  0.004132    1.267198
# 4                    (chicken)  (mineral water)            0.059992  ...  1.594172  0.008497    1.228438
# ..                         ...              ...                 ...  ...       ...       ...         ...
# 58       (milk, mineral water)      (spaghetti)            0.047994  ...  1.882589  0.007375    1.228597
# 59      (spaghetti, olive oil)  (mineral water)            0.022930  ...  1.878079  0.004799    1.378954
# 60  (olive oil, mineral water)      (spaghetti)            0.027596  ...  2.136468  0.005460    1.315071
# 61       (spaghetti, pancakes)  (mineral water)            0.025197  ...  1.908923  0.005459    1.397557
# 62   (pancakes, mineral water)      (spaghetti)            0.033729  ...  1.952333  0.005593    1.251198
#
# [63 rows x 9 columns]

# %%
rules = rules[['antecedents','consequents','support','confidence']]

# %%
rules.head()
# Out:
#   antecedents      consequents   support  confidence
# 0   (avocado)  (mineral water)  0.011598    0.348000
# 1   (burgers)           (eggs)  0.028796    0.330275
# 2      (cake)  (mineral water)  0.027463    0.338816
# 3   (cereals)  (mineral water)  0.010265    0.398964
# 4   (chicken)  (mineral water)  0.022797    0.380000

# %%
rules[rules['antecedents']=={'cake'}]
# Out:
#   antecedents      consequents   support  confidence
# 2      (cake)  (mineral water)  0.027463    0.338816
