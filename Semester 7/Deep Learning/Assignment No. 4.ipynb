# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, recall_score, accuracy_score, precision_score
RANDOM_SEED = 2021 
TEST_PCT = 0.3
LABELS = ["Normal","Fraud"]

# %%
dataset = pd.read_csv("creditcard.csv")
print(list(dataset.columns))
dataset.describe()
# Out:
# ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']
#                 Time            V1            V2            V3            V4
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000  \
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
#check for any  nullvalues 
print("Any nulls in the dataset ",dataset.isnull().values.any() )
print('-------')
print("No. of unique labels ", len(dataset['Class'].unique()))
print("Label values ",dataset.Class.unique())
#0 is for normal credit card transaction
#1 is for fraudulent credit card transaction
print('-------')
print("Break down of the Normal and Fraud Transactions")
print(pd.value_counts(dataset['Class'], sort = True) )
# Out:
# Any nulls in the dataset  False
# -------
# No. of unique labels  2
# Label values  [0 1]
# -------
# Break down of the Normal and Fraud Transactions
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
#Visualizing the imbalanced dataset
count_classes = pd.value_counts(dataset['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.xticks(range(len(dataset['Class'].unique())), dataset.Class.unique())
plt.title("Frequency by observation number")
plt.xlabel("Class")
plt.ylabel("Number of Observations");

# %%
# Save the normal and fradulent transactions in separate dataframe
normal_dataset = dataset[dataset.Class == 0] 
fraud_dataset = dataset[dataset.Class == 1]
#Visualize transactionamounts for normal and fraudulent transactions
bins = np.linspace(200, 2500, 100) # Return evenly spaced numbers over a specified interval.
plt.hist(normal_dataset.Amount, bins=bins, alpha=1, density=True, label='Normal')
plt.hist(fraud_dataset.Amount, bins=bins, alpha=0.5, density=True, label='Fraud')
plt.legend(loc='upper right')
plt.title("Transaction amount vs Percentage of transactions")
plt.xlabel("Transaction amount (USD)")
plt.ylabel("Percentage of transactions");
plt.show()

# %%
'''Time and Amount are the columns that are not scaled, so applying StandardScaler to only Amount and Time columns. 
Normalizing the values between 0 and 1 did not work great for the dataset.'''

# %%
sc=StandardScaler()
dataset['Time'] = sc.fit_transform(dataset['Time'].values.reshape(-1, 1))
dataset['Amount'] = sc.fit_transform(dataset['Amount'].values.reshape(-1, 1))

# %%
dataset['Amount']
# Out:
# 0         0.244964
# 1        -0.342475
# 2         1.160686
# 3         0.140534
# 4        -0.073403
#             ...
# 284802   -0.350151
# 284803   -0.254117
# 284804   -0.081839
# 284805   -0.313249
# 284806    0.514355
# Name: Amount, Length: 284807, dtype: float64

# %%
train_x, test_x = train_test_split(dataset, test_size=TEST_PCT, random_state=RANDOM_SEED)
train_x = train_x[train_x.Class == 0]       # where normal transactions
train_x = train_x.drop(['Class'], axis=1)   # drop the class column


test_y = test_x['Class']                    # save the class column for the test set
test_x = test_x.drop(['Class'], axis=1)     # drop the class column

train_x = train_x.values                    # transform to ndarray
test_x = test_x.values                      # transform to ndarray

# %% [markdown]
# #### Autoencoder Layer Structure and Parameters
# Autoencoder has symmetric encoding and decoding layers that are "dense". We are reducing the input into some form of simplified encoding and then expanding it again. The input and output dimension is the feature space (e.g. 30 columns), so the encoding layer should be smaller by an amount that expect to represent some feature. In this case, I am encoding 30 columns into 14 dimensions so I am expecting high-level features to be represented by roughly two columns (30/14 = 2.1). Of those high-level features, I am expecting them to map to roughly seven hidden/latent features in the data.
#
# Additionally, the epochs, batch size, learning rate, learning policy, and activation functions were all set to values empirically good values.

# %%
nb_epoch = 50
batch_size = 64
input_dim = train_x.shape[1] #num of columns, 30
encoding_dim = 14
hidden_dim_1 = int(encoding_dim / 2) #
hidden_dim_2=4  
learning_rate = 1e-7

# %%
#input Layer
input_layer = tf.keras.layers.Input(shape=(input_dim, ))

#Encoder
encoder = tf.keras.layers.Dense(encoding_dim, activation="tanh",                                
                        activity_regularizer=tf.keras.regularizers.l2(learning_rate))(input_layer)
# encoder=tf.keras.layers.Dropout(0.2)(encoder)
encoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)
encoder = tf.keras.layers.Dense(hidden_dim_2, activation=tf.nn.leaky_relu)(encoder)

# Decoder
decoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)
# decoder=tf.keras.layers.Dropout(0.2)(decoder)
decoder = tf.keras.layers.Dense(encoding_dim, activation='relu')(decoder)
decoder = tf.keras.layers.Dense(input_dim, activation='tanh')(decoder)

#Autoencoder
autoencoder = tf.keras.Model(inputs=input_layer, outputs=decoder)
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 30)]              0
#
#  dense_6 (Dense)             (None, 14)                434
#
#  dense_7 (Dense)             (None, 7)                 105
#
#  dense_8 (Dense)             (None, 4)                 32
#
#  dense_9 (Dense)             (None, 7)                 35
#
#  dense_10 (Dense)            (None, 14)                112
#
#  dense_11 (Dense)            (None, 30)                450
#
# =================================================================
# Total params: 1,168
# Trainable params: 1,168
# Non-trainable params: 0
# _________________________________________________________________

# %%
"""Define the callbacks for checkpoints and early stopping"""

cp = tf.keras.callbacks.ModelCheckpoint(filepath="autoencoder_fraud.h5",
                               mode='min', monitor='val_loss', verbose=2, save_best_only=True)
# define our early stopping
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.0001,
    patience=10,
    verbose=1, 
    mode='min',
    restore_best_weights=True)

# %%
#Compile the Autoencoder

autoencoder.compile(metrics=['accuracy'],
                    loss='mean_squared_error',
                    optimizer='adam')

# %%
#Train the Autoencoder

history = autoencoder.fit(train_x, train_x,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(test_x, test_x),
                    verbose=1,
                    callbacks=[cp, early_stop]
                    ).history
# Out:
# Epoch 1/50
# 3083/3110 [============================>.] - ETA: 0s - loss: 0.7791 - accuracy: 0.3768
# Epoch 1: val_loss improved from inf to 0.74049, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 9s 2ms/step - loss: 0.7776 - accuracy: 0.3773 - val_loss: 0.7405 - val_accuracy: 0.4284
# Epoch 2/50
# 3105/3110 [============================>.] - ETA: 0s - loss: 0.6920 - accuracy: 0.4370
# Epoch 2: val_loss improved from 0.74049 to 0.71262, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6920 - accuracy: 0.4370 - val_loss: 0.7126 - val_accuracy: 0.4501
# Epoch 3/50
# 3104/3110 [============================>.] - ETA: 0s - loss: 0.6754 - accuracy: 0.4522
# Epoch 3: val_loss improved from 0.71262 to 0.70220, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6750 - accuracy: 0.4521 - val_loss: 0.7022 - val_accuracy: 0.4513
# Epoch 4/50
# 3101/3110 [============================>.] - ETA: 0s - loss: 0.6673 - accuracy: 0.4571
# Epoch 4: val_loss improved from 0.70220 to 0.69708, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6673 - accuracy: 0.4570 - val_loss: 0.6971 - val_accuracy: 0.4631
# Epoch 5/50
# 3087/3110 [============================>.] - ETA: 0s - loss: 0.6633 - accuracy: 0.4597
# Epoch 5: val_loss improved from 0.69708 to 0.69157, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 3ms/step - loss: 0.6627 - accuracy: 0.4597 - val_loss: 0.6916 - val_accuracy: 0.4629
# Epoch 6/50
# 3096/3110 [============================>.] - ETA: 0s - loss: 0.6593 - accuracy: 0.4569
# Epoch 6: val_loss improved from 0.69157 to 0.68839, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6587 - accuracy: 0.4569 - val_loss: 0.6884 - val_accuracy: 0.4596
# Epoch 7/50
# 3086/3110 [============================>.] - ETA: 0s - loss: 0.6560 - accuracy: 0.4633
# Epoch 7: val_loss improved from 0.68839 to 0.68431, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6549 - accuracy: 0.4631 - val_loss: 0.6843 - val_accuracy: 0.4608
# Epoch 8/50
# 3093/3110 [============================>.] - ETA: 0s - loss: 0.6510 - accuracy: 0.4579
# Epoch 8: val_loss improved from 0.68431 to 0.67889, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6508 - accuracy: 0.4579 - val_loss: 0.6789 - val_accuracy: 0.4536
# Epoch 9/50
# 3108/3110 [============================>.] - ETA: 0s - loss: 0.6439 - accuracy: 0.4503
# Epoch 9: val_loss improved from 0.67889 to 0.67459, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6438 - accuracy: 0.4503 - val_loss: 0.6746 - val_accuracy: 0.4511
# Epoch 10/50
# 3084/3110 [============================>.] - ETA: 0s - loss: 0.6406 - accuracy: 0.4515
# Epoch 10: val_loss improved from 0.67459 to 0.67242, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6406 - accuracy: 0.4515 - val_loss: 0.6724 - val_accuracy: 0.4531
# Epoch 11/50
# 3092/3110 [============================>.] - ETA: 0s - loss: 0.6385 - accuracy: 0.4511
# Epoch 11: val_loss improved from 0.67242 to 0.67047, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6388 - accuracy: 0.4512 - val_loss: 0.6705 - val_accuracy: 0.4537
# Epoch 12/50
# 3109/3110 [============================>.] - ETA: 0s - loss: 0.6374 - accuracy: 0.4498
# Epoch 12: val_loss improved from 0.67047 to 0.66997, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6373 - accuracy: 0.4498 - val_loss: 0.6700 - val_accuracy: 0.4534
# Epoch 13/50
# 3106/3110 [============================>.] - ETA: 0s - loss: 0.6359 - accuracy: 0.4506
# Epoch 13: val_loss improved from 0.66997 to 0.66864, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 3ms/step - loss: 0.6360 - accuracy: 0.4506 - val_loss: 0.6686 - val_accuracy: 0.4519
# Epoch 14/50
# 3090/3110 [============================>.] - ETA: 0s - loss: 0.6342 - accuracy: 0.4504
# Epoch 14: val_loss improved from 0.66864 to 0.66624, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6348 - accuracy: 0.4504 - val_loss: 0.6662 - val_accuracy: 0.4518
# Epoch 15/50
# 3087/3110 [============================>.] - ETA: 0s - loss: 0.6336 - accuracy: 0.4491
# Epoch 15: val_loss improved from 0.66624 to 0.66462, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6338 - accuracy: 0.4490 - val_loss: 0.6646 - val_accuracy: 0.4424
# Epoch 16/50
# 3097/3110 [============================>.] - ETA: 0s - loss: 0.6332 - accuracy: 0.4457
# Epoch 16: val_loss did not improve from 0.66462
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6328 - accuracy: 0.4457 - val_loss: 0.6647 - val_accuracy: 0.4474
# Epoch 17/50
# 3084/3110 [============================>.] - ETA: 0s - loss: 0.6321 - accuracy: 0.4443
# Epoch 17: val_loss did not improve from 0.66462
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6322 - accuracy: 0.4442 - val_loss: 0.6664 - val_accuracy: 0.4453
# Epoch 18/50
# 3093/3110 [============================>.] - ETA: 0s - loss: 0.6316 - accuracy: 0.4390
# Epoch 18: val_loss improved from 0.66462 to 0.66251, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 10s 3ms/step - loss: 0.6316 - accuracy: 0.4390 - val_loss: 0.6625 - val_accuracy: 0.4391
# Epoch 19/50
# 3108/3110 [============================>.] - ETA: 0s - loss: 0.6303 - accuracy: 0.4349
# Epoch 19: val_loss improved from 0.66251 to 0.66195, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 10s 3ms/step - loss: 0.6302 - accuracy: 0.4349 - val_loss: 0.6619 - val_accuracy: 0.4344
# Epoch 20/50
# 3098/3110 [============================>.] - ETA: 0s - loss: 0.6296 - accuracy: 0.4349
# Epoch 20: val_loss improved from 0.66195 to 0.66114, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 10s 3ms/step - loss: 0.6295 - accuracy: 0.4349 - val_loss: 0.6611 - val_accuracy: 0.4305
# Epoch 21/50
# 3088/3110 [============================>.] - ETA: 0s - loss: 0.6288 - accuracy: 0.4314
# Epoch 21: val_loss improved from 0.66114 to 0.65975, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 9s 3ms/step - loss: 0.6284 - accuracy: 0.4314 - val_loss: 0.6597 - val_accuracy: 0.4317
# Epoch 22/50
# 3108/3110 [============================>.] - ETA: 0s - loss: 0.6274 - accuracy: 0.4297
# Epoch 22: val_loss improved from 0.65975 to 0.65946, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 9s 3ms/step - loss: 0.6273 - accuracy: 0.4297 - val_loss: 0.6595 - val_accuracy: 0.4302
# Epoch 23/50
# 3098/3110 [============================>.] - ETA: 0s - loss: 0.6266 - accuracy: 0.4296
# Epoch 23: val_loss improved from 0.65946 to 0.65764, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 11s 3ms/step - loss: 0.6263 - accuracy: 0.4296 - val_loss: 0.6576 - val_accuracy: 0.4287
# Epoch 24/50
# 3100/3110 [============================>.] - ETA: 0s - loss: 0.6252 - accuracy: 0.4276
# Epoch 24: val_loss improved from 0.65764 to 0.65571, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 13s 4ms/step - loss: 0.6251 - accuracy: 0.4276 - val_loss: 0.6557 - val_accuracy: 0.4269
# Epoch 25/50
# 3094/3110 [============================>.] - ETA: 0s - loss: 0.6244 - accuracy: 0.4259
# Epoch 25: val_loss improved from 0.65571 to 0.65530, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 10s 3ms/step - loss: 0.6238 - accuracy: 0.4260 - val_loss: 0.6553 - val_accuracy: 0.4229
# Epoch 26/50
# 3108/3110 [============================>.] - ETA: 0s - loss: 0.6229 - accuracy: 0.4246
# Epoch 26: val_loss improved from 0.65530 to 0.65362, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 3ms/step - loss: 0.6228 - accuracy: 0.4247 - val_loss: 0.6536 - val_accuracy: 0.4234
# Epoch 27/50
# 3107/3110 [============================>.] - ETA: 0s - loss: 0.6217 - accuracy: 0.4244
# Epoch 27: val_loss did not improve from 0.65362
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6218 - accuracy: 0.4243 - val_loss: 0.6539 - val_accuracy: 0.4239
# Epoch 28/50
# 3103/3110 [============================>.] - ETA: 0s - loss: 0.6209 - accuracy: 0.4243
# Epoch 28: val_loss improved from 0.65362 to 0.65312, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6210 - accuracy: 0.4242 - val_loss: 0.6531 - val_accuracy: 0.4232
# Epoch 29/50
# 3084/3110 [============================>.] - ETA: 0s - loss: 0.6197 - accuracy: 0.4248
# Epoch 29: val_loss improved from 0.65312 to 0.65224, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6203 - accuracy: 0.4247 - val_loss: 0.6522 - val_accuracy: 0.4231
# Epoch 30/50
# 3105/3110 [============================>.] - ETA: 0s - loss: 0.6193 - accuracy: 0.4238
# Epoch 30: val_loss improved from 0.65224 to 0.65032, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6196 - accuracy: 0.4239 - val_loss: 0.6503 - val_accuracy: 0.4238
# Epoch 31/50
# 3091/3110 [============================>.] - ETA: 0s - loss: 0.6186 - accuracy: 0.4236
# Epoch 31: val_loss did not improve from 0.65032
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6191 - accuracy: 0.4237 - val_loss: 0.6510 - val_accuracy: 0.4255
# Epoch 32/50
# 3094/3110 [============================>.] - ETA: 0s - loss: 0.6187 - accuracy: 0.4239
# Epoch 32: val_loss did not improve from 0.65032
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6188 - accuracy: 0.4238 - val_loss: 0.6503 - val_accuracy: 0.4262
# Epoch 33/50
# 3094/3110 [============================>.] - ETA: 0s - loss: 0.6187 - accuracy: 0.4243
# Epoch 33: val_loss improved from 0.65032 to 0.65003, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6184 - accuracy: 0.4243 - val_loss: 0.6500 - val_accuracy: 0.4247
# Epoch 34/50
# 3088/3110 [============================>.] - ETA: 0s - loss: 0.6180 - accuracy: 0.4255
# Epoch 34: val_loss improved from 0.65003 to 0.64979, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6179 - accuracy: 0.4254 - val_loss: 0.6498 - val_accuracy: 0.4313
# Epoch 35/50
# 3080/3110 [============================>.] - ETA: 0s - loss: 0.6185 - accuracy: 0.4263
# Epoch 35: val_loss improved from 0.64979 to 0.64949, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6177 - accuracy: 0.4265 - val_loss: 0.6495 - val_accuracy: 0.4285
# Epoch 36/50
# 3088/3110 [============================>.] - ETA: 0s - loss: 0.6174 - accuracy: 0.4268
# Epoch 36: val_loss improved from 0.64949 to 0.64865, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6174 - accuracy: 0.4268 - val_loss: 0.6487 - val_accuracy: 0.4319
# Epoch 37/50
# 3075/3110 [============================>.] - ETA: 0s - loss: 0.6164 - accuracy: 0.4286
# Epoch 37: val_loss did not improve from 0.64865
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6173 - accuracy: 0.4286 - val_loss: 0.6493 - val_accuracy: 0.4281
# Epoch 38/50
# 3085/3110 [============================>.] - ETA: 0s - loss: 0.6162 - accuracy: 0.4293
# Epoch 38: val_loss improved from 0.64865 to 0.64863, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 8s 3ms/step - loss: 0.6169 - accuracy: 0.4291 - val_loss: 0.6486 - val_accuracy: 0.4314
# Epoch 39/50
# 3092/3110 [============================>.] - ETA: 0s - loss: 0.6169 - accuracy: 0.4303
# Epoch 39: val_loss did not improve from 0.64863
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6166 - accuracy: 0.4304 - val_loss: 0.6493 - val_accuracy: 0.4341
# Epoch 40/50
# 3104/3110 [============================>.] - ETA: 0s - loss: 0.6164 - accuracy: 0.4316
# Epoch 40: val_loss improved from 0.64863 to 0.64721, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6163 - accuracy: 0.4316 - val_loss: 0.6472 - val_accuracy: 0.4372
# Epoch 41/50
# 3096/3110 [============================>.] - ETA: 0s - loss: 0.6159 - accuracy: 0.4334
# Epoch 41: val_loss improved from 0.64721 to 0.64697, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6161 - accuracy: 0.4334 - val_loss: 0.6470 - val_accuracy: 0.4373
# Epoch 42/50
# 3090/3110 [============================>.] - ETA: 0s - loss: 0.6163 - accuracy: 0.4336
# Epoch 42: val_loss improved from 0.64697 to 0.64682, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6160 - accuracy: 0.4336 - val_loss: 0.6468 - val_accuracy: 0.4334
# Epoch 43/50
# 3105/3110 [============================>.] - ETA: 0s - loss: 0.6157 - accuracy: 0.4346
# Epoch 43: val_loss did not improve from 0.64682
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6158 - accuracy: 0.4346 - val_loss: 0.6473 - val_accuracy: 0.4369
# Epoch 44/50
# 3108/3110 [============================>.] - ETA: 0s - loss: 0.6156 - accuracy: 0.4346
# Epoch 44: val_loss did not improve from 0.64682
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6155 - accuracy: 0.4347 - val_loss: 0.6473 - val_accuracy: 0.4360
# Epoch 45/50
# 3089/3110 [============================>.] - ETA: 0s - loss: 0.6157 - accuracy: 0.4345
# Epoch 45: val_loss did not improve from 0.64682
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6154 - accuracy: 0.4348 - val_loss: 0.6471 - val_accuracy: 0.4335
# Epoch 46/50
# 3090/3110 [============================>.] - ETA: 0s - loss: 0.6156 - accuracy: 0.4349
# Epoch 46: val_loss did not improve from 0.64682
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6153 - accuracy: 0.4348 - val_loss: 0.6480 - val_accuracy: 0.4354
# Epoch 47/50
# 3096/3110 [============================>.] - ETA: 0s - loss: 0.6153 - accuracy: 0.4343
# Epoch 47: val_loss did not improve from 0.64682
# 3110/3110 [==============================] - 8s 2ms/step - loss: 0.6152 - accuracy: 0.4343 - val_loss: 0.6471 - val_accuracy: 0.4335
# Epoch 48/50
# 3094/3110 [============================>.] - ETA: 0s - loss: 0.6160 - accuracy: 0.4339
# Epoch 48: val_loss did not improve from 0.64682
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6151 - accuracy: 0.4340 - val_loss: 0.6482 - val_accuracy: 0.4374
# Epoch 49/50
# 3104/3110 [============================>.] - ETA: 0s - loss: 0.6148 - accuracy: 0.4342
# Epoch 49: val_loss improved from 0.64682 to 0.64680, saving model to autoencoder_fraud.h5
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6149 - accuracy: 0.4342 - val_loss: 0.6468 - val_accuracy: 0.4384
# Epoch 50/50
# 3086/3110 [============================>.] - ETA: 0s - loss: 0.6139 - accuracy: 0.4335
# Epoch 50: val_loss did not improve from 0.64680
# 3110/3110 [==============================] - 7s 2ms/step - loss: 0.6147 - accuracy: 0.4337 - val_loss: 0.6477 - val_accuracy: 0.4380

# %%
#Plot training and test loss

plt.plot(history['loss'], linewidth=2, label='Train')
plt.plot(history['val_loss'], linewidth=2, label='Test')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.ylim(ymin=0.70,ymax=1)
plt.show()

# %%
"""Detect Anomalies on test data

Anomalies are data points where the reconstruction loss is higher

To calculate the reconstruction loss on test data, 
predict the test data and calculate the mean square error between the test data and the reconstructed test data."""

test_x_predictions = autoencoder.predict(test_x)
mse = np.mean(np.power(test_x - test_x_predictions, 2), axis=1)
error_df = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': test_y})
error_df.describe()
# Out:
# 2671/2671 [==============================] - 3s 1ms/step
#        Reconstruction_error    True_class
# count          85443.000000  85443.000000
# mean               0.647702      0.001662
# std                3.550923      0.040733
# min                0.024556      0.000000
# 25%                0.146707      0.000000
# 50%                0.252017      0.000000
# 75%                0.484951      0.000000
# max              304.087335      1.000000

# %%
#Plotting the test data points and their respective reconstruction error sets a threshold value to visualize 
#if the threshold value needs to be adjusted.

threshold_fixed = 50
groups = error_df.groupby('True_class')
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold_fixed, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for normal and fraud data")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
'''Detect anomalies as points where the reconstruction loss is greater than a fixed threshold. 
Here we see that a value of 52 for the threshold will be good.

Evaluating the performance of the anomaly detection'''

threshold_fixed =52
pred_y = [1 if e > threshold_fixed else 0 for e in error_df.Reconstruction_error.values]
error_df['pred'] =pred_y
conf_matrix = confusion_matrix(error_df.True_class, pred_y)
plt.figure(figsize=(4, 4))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# print Accuracy, precision and recall
print(" Accuracy: ",accuracy_score(error_df['True_class'], error_df['pred']))
print(" Recall: ",recall_score(error_df['True_class'], error_df['pred']))
print(" Precision: ",precision_score(error_df['True_class'], error_df['pred']))
# Out:
#  Accuracy:  0.9981742214107651
#  Recall:  0.20422535211267606
#  Precision:  0.4027777777777778

# %%
'''As our dataset is highly imbalanced, we see a high accuracy but a low recall and precision.

Things to further improve precision and recall would add more relevant features, 
different architecture for autoencoder, different hyperparameters, or a different algorithm.'''
