# %% [markdown]
# ## Assignment 4

# %%
import pandas as pd

# %%
df = pd.read_csv('fb.csv')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441   Photo         2          12             4          3  \
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.iloc[[2,4,6],[2,3]] #[rows],[colunms]
# Out:
#    Category  Post Month
# 2         3          12
# 4         2          12
# 6         3          12

# %%
df.iloc[-1::-1 , 1:9:3] # [startRow:endRow-1:step] [startCol:endCol-1:step]
# Out:
#       Type  Post Weekday  Lifetime Post Total Reach
# 499  Photo             4                       4188
# 498  Photo             4                       4156
# 497  Photo             5                       3778
# 496  Photo             5                       3480
# 495  Photo             7                       4684

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0            139441   Photo         2          12             4          3  \
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions
# 0   0.0                       2752                             5091  \
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
df.columns.to_list()
# Out:
# ['Page total likes',
#  'Type',
#  'Category',
#  'Post Month',
#  'Post Weekday',
#  'Post Hour',
#  'Paid',
#  'Lifetime Post Total Reach',
#  'Lifetime Post Total Impressions',
#  'Lifetime Engaged Users',
#  'Lifetime Post Consumers',
#  'Lifetime Post Consumptions',
#  'Lifetime Post Impressions by people who have liked your Page',
#  'Lifetime Post reach by people who like your Page',
#  'Lifetime People who have liked your Page and engaged with your post',
#  'comment',
#  'like',
#  'share',
#  'Total Interactions']

# %%
df.loc[3] #give row information, recognizes integers as labels, returns a series
# df.loc['Type'] # give an error, because first index is looking for a row index
# https://towardsdatascience.com/a-python-beginners-look-at-loc-part-1-cb1e1e565ec2
# Out:
# Page total likes                                                       139441
# Type                                                                    Photo
# Category                                                                    2
# Post Month                                                                 12
# Post Weekday                                                                2
# Post Hour                                                                  10
# Paid                                                                      1.0
# Lifetime Post Total Reach                                               50128
# Lifetime Post Total Impressions                                         87991
# Lifetime Engaged Users                                                   2211
# Lifetime Post Consumers                                                   790
# Lifetime Post Consumptions                                               1119
# ...

# %%
df.loc[df['Post Month'] < 10].head(5) # Creates a boolean mask
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 155            135700  Photo         2           9             3          7  \
# 156            135700  Photo         2           9             2         11
# 157            135700  Photo         3           9             2          2
# 158            135700  Photo         2           9             1         10
# 159            135617  Photo         2           9             1          3
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions
# 155   0.0                       1685                             2999  \
# 156   0.0                       3756                             7094
# 157   0.0                       2656                             4862
# 158   0.0                       5086                             9493
# 159   1.0                       2055                             3915
#
#      Lifetime Engaged Users  Lifetime Post Consumers
# ...

# %%
df[['Type','Category']].head(5)
# Out:
#      Type  Category
# 0   Photo         2
# 1  Status         2
# 2   Photo         3
# 3   Photo         2
# 4   Photo         2

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Creating data Subsets

# %%
sub = df[['Type','Category','like','comment','share']]

# %%
sub
# Out:
#        Type  Category    like  comment  share
# 0     Photo         2    79.0        4   17.0
# 1    Status         2   130.0        5   29.0
# 2     Photo         3    66.0        0   14.0
# 3     Photo         2  1572.0       58  147.0
# 4     Photo         2   325.0       19   49.0
# ..      ...       ...     ...      ...    ...
# 495   Photo         3    53.0        5   26.0
# 496   Photo         2    53.0        0   22.0
# 497   Photo         1    93.0        4   18.0
# 498   Photo         3    91.0        7   38.0
# 499   Photo         2    91.0        0   28.0
#
# [500 rows x 5 columns]

# %%
sub.shape
# Out:
# (500, 5)

# %%
like_filter = sub.loc[sub['like']>100]

# %%
like_filter
# Out:
#        Type  Category    like  comment  share
# 1    Status         2   130.0        5   29.0
# 3     Photo         2  1572.0       58  147.0
# 4     Photo         2   325.0       19   49.0
# 5    Status         2   152.0        1   33.0
# 6     Photo         3   249.0        3   27.0
# ..      ...       ...     ...      ...    ...
# 488   Photo         3   277.0       21   80.0
# 491   Photo         3   105.0        1   46.0
# 492    Link         1   128.0        0    9.0
# 493   Photo         3   185.0       17   55.0
# 494   Photo         3   125.0       10   41.0
#
# [252 rows x 5 columns]

# %%
like_filter.shape
# Out:
# (252, 5)

# %%
like_filter.head()
# Out:
#      Type  Category    like  comment  share
# 1  Status         2   130.0        5   29.0
# 3   Photo         2  1572.0       58  147.0
# 4   Photo         2   325.0       19   49.0
# 5  Status         2   152.0        1   33.0
# 6   Photo         3   249.0        3   27.0

# %%
fil = sub[(sub['like'] > 100 ) & (sub['share'] >40)]

# %%
fil
# Out:
#        Type  Category    like  comment  share
# 3     Photo         2  1572.0       58  147.0
# 4     Photo         2   325.0       19   49.0
# 26   Status         2   412.0       10   72.0
# 28    Photo         2   523.0       36   63.0
# 32    Photo         3   155.0        2   47.0
# ..      ...       ...     ...      ...    ...
# 480   Photo         2   360.0       56   99.0
# 488   Photo         3   277.0       21   80.0
# 491   Photo         3   105.0        1   46.0
# 493   Photo         3   185.0       17   55.0
# 494   Photo         3   125.0       10   41.0
#
# [84 rows x 5 columns]

# %%
fil.shape
# Out:
# (84, 5)

# %%
fil.to_html('output.html',index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Merging the Data

# %%
newdata = pd.read_csv('fb.csv')

# %%
merged = df.merge(newdata) # for combining data on common columns or indices

# %%
merged.shape
# Out:
# (500, 19)

# %%
df1 = df[df['like'] > 200] 
df2 = df[df['Category'] == 3]
df1.merge(df2 , how='outer').shape
df1

# %% [markdown]
# #### [More about Merge and Join](https://realpython.com/pandas-merge-join-and-concat/)

# %% [markdown]
# ----------------

# %% [markdown]
# ## 3. Sorting Data

# %%
sorted_df = fil.sort_values(by='comment',ascending=False)

# %%
sorted_df.head()
# Out:
#        Type  Category    like  comment  share
# 244   Photo         2  5172.0      372  790.0
# 460   Photo         3  1546.0      146  181.0
# 168   Photo         1  1622.0      144  208.0
# 142  Status         2   859.0       60   90.0
# 3     Photo         2  1572.0       58  147.0

# %% [markdown]
# --------

# %% [markdown]
# ## 4. Transpose

# %%
fil.head()
# Out:
#       Type  Category    like  comment  share
# 3    Photo         2  1572.0       58  147.0
# 4    Photo         2   325.0       19   49.0
# 26  Status         2   412.0       10   72.0
# 28   Photo         2   523.0       36   63.0
# 32   Photo         3   155.0        2   47.0

# %%
fil_t = fil.T # transpose of matrix

# %%
fil_t.head()
# Out:
#              3      4       26     28     32     56     67     71      72
# Type       Photo  Photo  Status  Photo  Photo  Photo  Photo  Video  Status  \
# Category       2      2       2      2      3      1      1      1       3
# like      1572.0  325.0   412.0  523.0  155.0  164.0  697.0  449.0   226.0
# comment       58     19      10     36      2      2     20     17       3
# share      147.0   49.0    72.0   63.0   47.0   54.0   70.0   84.0    44.0
#
#             73   ...    462    469    471    473    476    480    488    491
# Type      Photo  ...  Photo  Photo  Photo  Photo  Photo  Photo  Photo  Photo  \
# Category      1  ...      3      3      3      3      1      2      3      3
# like      172.0  ...  214.0  193.0  160.0  136.0  579.0  360.0  277.0  105.0
# comment      14  ...     19     10      7      4      7     56     21      1
# share      47.0  ...   78.0   61.0   57.0   42.0   47.0   99.0   80.0   46.0
#
#             493    494
# Type      Photo  Photo
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Melting

# %%
fil_t.melt()
# Out:
#      variable   value
# 0           3   Photo
# 1           3       2
# 2           3  1572.0
# 3           3      58
# 4           3   147.0
# ..        ...     ...
# 415       494   Photo
# 416       494       3
# 417       494   125.0
# 418       494      10
# 419       494    41.0
#
# [420 rows x 2 columns]

# %%
fil.melt() # converting wide data in long data
# Out:
#     variable   value
# 0       Type   Photo
# 1       Type   Photo
# 2       Type  Status
# 3       Type   Photo
# 4       Type   Photo
# ..       ...     ...
# 415    share    99.0
# 416    share    80.0
# 417    share    46.0
# 418    share    55.0
# 419    share    41.0
#
# [420 rows x 2 columns]

# %%
fil.melt(id_vars='Category')
# Out:
#      Category variable   value
# 0           2     Type   Photo
# 1           2     Type   Photo
# 2           2     Type  Status
# 3           2     Type   Photo
# 4           3     Type   Photo
# ..        ...      ...     ...
# 331         2    share    99.0
# 332         3    share    80.0
# 333         3    share    46.0
# 334         3    share    55.0
# 335         3    share    41.0
#
# [336 rows x 3 columns]

# %%
fil.melt(id_vars=['Category' , 'Type'])
# Out:
#      Category    Type variable   value
# 0           2   Photo     like  1572.0
# 1           2   Photo     like   325.0
# 2           2  Status     like   412.0
# 3           2   Photo     like   523.0
# 4           3   Photo     like   155.0
# ..        ...     ...      ...     ...
# 247         2   Photo    share    99.0
# 248         3   Photo    share    80.0
# 249         3   Photo    share    46.0
# 250         3   Photo    share    55.0
# 251         3   Photo    share    41.0
#
# [252 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 6. Casting

# %%
dummy = pd.get_dummies(fil) # Each variable is converted in as many 0/1 variables as there are different values. 
# Columns in the output are each named after a value; if the input is a DataFrame, 
# the name of the original variable is prepended to the value.

# %%
dummy.info
# Out:
#      Category    like  comment  share  Type_Link  Type_Photo  Type_Status
# 3           2  1572.0       58  147.0      False        True        False  \
# 4           2   325.0       19   49.0      False        True        False
# 26          2   412.0       10   72.0      False       False         True
# 28          2   523.0       36   63.0      False        True        False
# 32          3   155.0        2   47.0      False        True        False
# ..        ...     ...      ...    ...        ...         ...          ...
# 480         2   360.0       56   99.0      False        True        False
# 488         3   277.0       21   80.0      False        True        False
# 491         3   105.0        1   46.0      False        True        False
# 493         3   185.0       17   55.0      False        True        False
# 494         3   125.0       10   41.0      False        True        False
#
#      Type_Video
# 3         False
# 4         False
# 26        False
# ...

# %%
dummy['Category']=dummy['Category'].astype('object')

# %%
dir(fil) # returns all the attributes and properties related to that attribute
# even inbuilt functions
# Out:
# ['Category',
#  'T',
#  'Type',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
df['Type'].astype('string') # casting from object to string
# Out:
# 0       Photo
# 1      Status
# 2       Photo
# 3       Photo
# 4       Photo
#         ...
# 495     Photo
# 496     Photo
# 497     Photo
# 498     Photo
# 499     Photo
# Name: Type, Length: 500, dtype: string

# %% [markdown]
# # Assignment 7

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(x=df['Type'],height=df['like'])
# Out:
# <BarContainer object of 500 artists>

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441   Photo         2          12             4          3  \
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
plt.scatter(x=df['Lifetime Engaged Users'],y=df['like'])

# %%
plt.plot(df['Post Month'],df['Page total likes'],color='green',linestyle='dashed',linewidth='3')

# %%
fil.plot.area();

# %%
# %pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df['Type'] ,y=df['like'])
# Out:
# <Axes: xlabel='Type', ylabel='like'>

# %%
sns.boxplot( df['Post Hour'])
# Out:
# <Axes: >

# %%
l=[]
for i in range(1,13):
    l.append(sum(df['Post Month'] == i))

# %%
sns.lineplot(df['Post Month'])
# Out:
# <Axes: >

# %%
fil
# Out:
#        Type  Category    like  comment  share
# 3     Photo         2  1572.0       58  147.0
# 4     Photo         2   325.0       19   49.0
# 26   Status         2   412.0       10   72.0
# 28    Photo         2   523.0       36   63.0
# 32    Photo         3   155.0        2   47.0
# ..      ...       ...     ...      ...    ...
# 480   Photo         2   360.0       56   99.0
# 488   Photo         3   277.0       21   80.0
# 491   Photo         3   105.0        1   46.0
# 493   Photo         3   185.0       17   55.0
# 494   Photo         3   125.0       10   41.0
#
# [84 rows x 5 columns]

# %%
sns.scatterplot(x='like',y='share',hue='Type',data=df)
# Out:
# <Axes: xlabel='like', ylabel='share'>

# %%
sns.scatterplot(x='like',y='share',hue='Type',size='comment',data=df)
# Out:
# <Axes: xlabel='like', ylabel='share'>

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441   Photo         2          12             4          3  \
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
sns.lineplot(x='like',y='comment',data=df
            )
# Out:
# <Axes: xlabel='like', ylabel='comment'>
